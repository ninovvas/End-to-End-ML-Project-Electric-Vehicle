# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.impute import SimpleImputer

from sklearn.linear_model import LogisticRegression, LinearRegression

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV

from sklearn.metrics import classification_report

import mlflow

# %% [markdown]
# #  Data Set
# - https://www.kaggle.com/datasets/rajkumarpandey02/electric-vehicle-population-data/data

# %% [markdown]
# # Workflow To Be Followed
#
# - Step 1: Loading The Dataset
# - Step 2: Performing EDA
# - Step 3: Feature Engineering
# - Step 4: Model Training & Evaluation

# %%
experiment = mlflow.create_experiment(name = "Initial Tetsing")

# %%
run = mlflow.start_run(experiment_id = experiment, run_name="First Run")

# %% [markdown]
# ## Step 1: Loading The Dataset

# %%
# Load the data set
electric_vehicles = pd.read_csv("data/Electric_Vehicle_Population_Data.csv")

# %%
#>>> le = LabelEncoder()
#>>> le.fit([1, 2, 2, 6])
le = LabelEncoder()
models = le.fit_transform(electric_vehicles.Model.values)
states = le.fit_transform(electric_vehicles.State)
city = le.fit_transform(electric_vehicles.City)
county = le.fit_transform(electric_vehicles.County)

# %%
electric_vehicles.Model = models
electric_vehicles.State = states
electric_vehicles.City = city
electric_vehicles.County = county

# %%
electric_vehicles
# Out:
#         VIN (1-10)  County  City  State  Postal Code  Model Year     Make  \
# 0       5YJ3E1EA0K     155   592     44      98512.0        2019    TESLA
# 1       1N4BZ1DV4N      67   107     44      98236.0        2022   NISSAN
# 2       5YJ3E1EA0L     142   533     44      98290.0        2020    TESLA
# 3       5YJ3E1EBXL      73   510     44      98134.0        2020    TESLA
# 4       5YJSA1CP0D     142   157     44      98020.0        2013    TESLA
# ...            ...     ...   ...    ...          ...         ...      ...
# 135033  5YJSA1E29L      73   648     44      98004.0        2020    TESLA
# 135034  5YJYGDEE7M      73    67     44      98168.0        2021    TESLA
# 135035  5YJSA1E51N     112   208     44      98335.0        2022    TESLA
# 135036  KM8KMDAF3P      53   169     44      98823.0        2023  HYUNDAI
# 135037  1FADP5CU4E      75   440     44      98366.0        2014     FORD
#
#         Model                   Electric Vehicle Type  \
# 0          71          Battery Electric Vehicle (BEV)
# 1          69          Battery Electric Vehicle (BEV)
# 2          71          Battery Electric Vehicle (BEV)
# 3          71          Battery Electric Vehicle (BEV)
# 4          72          Battery Electric Vehicle (BEV)
# ...       ...                                     ...
# 135033     72          Battery Electric Vehicle (BEV)
# 135034     74          Battery Electric Vehicle (BEV)
# 135035     72          Battery Electric Vehicle (BEV)
# 135036     63          Battery Electric Vehicle (BEV)
# 135037     20  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                 Clean Alternative Fuel Vehicle Eligible           220.0
# 1       Eligibility unknown as battery range has not b...             0.0
# 2                 Clean Alternative Fuel Vehicle Eligible           266.0
# 3                 Clean Alternative Fuel Vehicle Eligible           322.0
# 4                 Clean Alternative Fuel Vehicle Eligible           208.0
# ...                                                   ...             ...
# 135033            Clean Alternative Fuel Vehicle Eligible           330.0
# 135034  Eligibility unknown as battery range has not b...             0.0
# 135035  Eligibility unknown as battery range has not b...             0.0
# 135036  Eligibility unknown as battery range has not b...             0.0
# 135037              Not eligible due to low battery range            19.0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 0             0.0                  22.0       242565116
# 1             0.0                  10.0       183272785
# 2             0.0                  44.0       112552366
# 3             0.0                  11.0         6336319
# 4         69900.0                  21.0       186212960
# ...           ...                   ...             ...
# 135033        0.0                  48.0       124776627
# 135034        0.0                  33.0       142857676
# 135035        0.0                  26.0       220157724
# 135036        0.0                  13.0       223872596
# 135037        0.0                  26.0       171102032
#
#                                       Vehicle Location  \
# 0        POINT (-122.91310169999997 47.01359260000004)
# 1        POINT (-122.35936399999997 47.97965520000008)
# 2        POINT (-122.09150499999998 47.91555500000004)
# 3       POINT (-122.32981499999994 47.579810000000066)
# 4                 POINT (-122.37507 47.80807000000004)
# ...                                                ...
# 135033   POINT (-122.20190499999995 47.61385000000007)
# 135034   POINT (-122.28645999999998 47.47613000000007)
# 135035   POINT (-122.58354539999999 47.32344880000005)
# 135036  POINT (-119.55512999999996 47.319360000000074)
# 135037   POINT (-122.63926499999997 47.53730000000007)
#
#                                          Electric Utility  2020 Census Tract
# 0                                  PUGET SOUND ENERGY INC       5.306701e+10
# 1                                  PUGET SOUND ENERGY INC       5.302997e+10
# 2                                  PUGET SOUND ENERGY INC       5.306105e+10
# 3            CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 4                                  PUGET SOUND ENERGY INC       5.306105e+10
# ...                                                   ...                ...
# 135033      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 135034       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303303e+10
# 135035  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305307e+10
# 135036                           PUD NO 2 OF GRANT COUNTY       5.302501e+10
# 135037                             PUGET SOUND ENERGY INC       5.303509e+10
#
# [135038 rows x 17 columns]

# %%
#Battery Electric Vehicle (BEV)
#df[(df == 'banana').any(axis=1)]
electric_vehicle_type = electric_vehicles[( electric_vehicles['Electric Vehicle Type'] == 'Battery Electric Vehicle (BEV)')]

# %%
plug_in_hybrid_electric_vehicle = electric_vehicles[( electric_vehicles['Electric Vehicle Type'] == 'Plug-in Hybrid Electric Vehicle (PHEV)')]

# %%
electric_vehicles["Electric Vehicle Type"].value_counts()
# Out:
# Electric Vehicle Type
# Battery Electric Vehicle (BEV)            103882
# Plug-in Hybrid Electric Vehicle (PHEV)     31156
# Name: count, dtype: int64

# %%
electric_vehicle_type_mapping = {type:idx for idx, type in enumerate(np.unique(electric_vehicles['Electric Vehicle Type']))}
#electric_vehicles

# %%
electric_vehicle_type_01 = electric_vehicles['Electric Vehicle Type'].map(electric_vehicle_type_mapping)

# %%
electric_vehicles['Electric Vehicle Type'] = electric_vehicle_type_01

# %%
electric_vehicles
# Out:
#         VIN (1-10)  County  City  State  Postal Code  Model Year     Make  \
# 0       5YJ3E1EA0K     155   592     44      98512.0        2019    TESLA
# 1       1N4BZ1DV4N      67   107     44      98236.0        2022   NISSAN
# 2       5YJ3E1EA0L     142   533     44      98290.0        2020    TESLA
# 3       5YJ3E1EBXL      73   510     44      98134.0        2020    TESLA
# 4       5YJSA1CP0D     142   157     44      98020.0        2013    TESLA
# ...            ...     ...   ...    ...          ...         ...      ...
# 135033  5YJSA1E29L      73   648     44      98004.0        2020    TESLA
# 135034  5YJYGDEE7M      73    67     44      98168.0        2021    TESLA
# 135035  5YJSA1E51N     112   208     44      98335.0        2022    TESLA
# 135036  KM8KMDAF3P      53   169     44      98823.0        2023  HYUNDAI
# 135037  1FADP5CU4E      75   440     44      98366.0        2014     FORD
#
#         Model  Electric Vehicle Type  \
# 0          71                      0
# 1          69                      0
# 2          71                      0
# 3          71                      0
# 4          72                      0
# ...       ...                    ...
# 135033     72                      0
# 135034     74                      0
# 135035     72                      0
# 135036     63                      0
# 135037     20                      1
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                 Clean Alternative Fuel Vehicle Eligible           220.0
# 1       Eligibility unknown as battery range has not b...             0.0
# 2                 Clean Alternative Fuel Vehicle Eligible           266.0
# 3                 Clean Alternative Fuel Vehicle Eligible           322.0
# 4                 Clean Alternative Fuel Vehicle Eligible           208.0
# ...                                                   ...             ...
# 135033            Clean Alternative Fuel Vehicle Eligible           330.0
# 135034  Eligibility unknown as battery range has not b...             0.0
# 135035  Eligibility unknown as battery range has not b...             0.0
# 135036  Eligibility unknown as battery range has not b...             0.0
# 135037              Not eligible due to low battery range            19.0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 0             0.0                  22.0       242565116
# 1             0.0                  10.0       183272785
# 2             0.0                  44.0       112552366
# 3             0.0                  11.0         6336319
# 4         69900.0                  21.0       186212960
# ...           ...                   ...             ...
# 135033        0.0                  48.0       124776627
# 135034        0.0                  33.0       142857676
# 135035        0.0                  26.0       220157724
# 135036        0.0                  13.0       223872596
# 135037        0.0                  26.0       171102032
#
#                                       Vehicle Location  \
# 0        POINT (-122.91310169999997 47.01359260000004)
# 1        POINT (-122.35936399999997 47.97965520000008)
# 2        POINT (-122.09150499999998 47.91555500000004)
# 3       POINT (-122.32981499999994 47.579810000000066)
# 4                 POINT (-122.37507 47.80807000000004)
# ...                                                ...
# 135033   POINT (-122.20190499999995 47.61385000000007)
# 135034   POINT (-122.28645999999998 47.47613000000007)
# 135035   POINT (-122.58354539999999 47.32344880000005)
# 135036  POINT (-119.55512999999996 47.319360000000074)
# 135037   POINT (-122.63926499999997 47.53730000000007)
#
#                                          Electric Utility  2020 Census Tract
# 0                                  PUGET SOUND ENERGY INC       5.306701e+10
# 1                                  PUGET SOUND ENERGY INC       5.302997e+10
# 2                                  PUGET SOUND ENERGY INC       5.306105e+10
# 3            CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 4                                  PUGET SOUND ENERGY INC       5.306105e+10
# ...                                                   ...                ...
# 135033      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 135034       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303303e+10
# 135035  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305307e+10
# 135036                           PUD NO 2 OF GRANT COUNTY       5.302501e+10
# 135037                             PUGET SOUND ENERGY INC       5.303509e+10
#
# [135038 rows x 17 columns]

# %%
electric_vehicle_type["Electric Range"] = electric_vehicle_type["Electric Range"].mask(electric_vehicle_type["Electric Range"].eq(0.0), electric_vehicle_type["Electric Range"].mean())
# Out:
# C:\Users\GETAC USER\AppData\Local\Temp\ipykernel_17628\4182502654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   electric_vehicle_type["Electric Range"] = electric_vehicle_type["Electric Range"].mask(electric_vehicle_type["Electric Range"].eq(0.0), electric_vehicle_type["Electric Range"].mean())

# %%
plug_in_hybrid_electric_vehicle["Electric Range"] = plug_in_hybrid_electric_vehicle["Electric Range"].mask(plug_in_hybrid_electric_vehicle["Electric Range"].eq(0.0), plug_in_hybrid_electric_vehicle["Electric Range"].mean())
# Out:
# C:\Users\GETAC USER\AppData\Local\Temp\ipykernel_17628\3645332798.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plug_in_hybrid_electric_vehicle["Electric Range"] = plug_in_hybrid_electric_vehicle["Electric Range"].mask(plug_in_hybrid_electric_vehicle["Electric Range"].eq(0.0), plug_in_hybrid_electric_vehicle["Electric Range"].mean())

# %%
#new_electric_vehicles = [electric_vehicle_type, plug_in_hybrid_electric_vehicle]
#new_electric_vehicles.appned(electric_vehicle_type)plug_in_hybrid_electric_vehicle
#new_electric_vehicles.append(plug_in_hybrid_electric_vehicle)

#frames = [df1, df2, df3]

electric_vehicles = pd.concat([electric_vehicle_type, plug_in_hybrid_electric_vehicle])

# %%
electric_vehicles
# Out:
#         VIN (1-10)  County  City  State  Postal Code  Model Year        Make  \
# 0       5YJ3E1EA0K     155   592     44      98512.0        2019       TESLA
# 1       1N4BZ1DV4N      67   107     44      98236.0        2022      NISSAN
# 2       5YJ3E1EA0L     142   533     44      98290.0        2020       TESLA
# 3       5YJ3E1EBXL      73   510     44      98134.0        2020       TESLA
# 4       5YJSA1CP0D     142   157     44      98020.0        2013       TESLA
# ...            ...     ...   ...    ...          ...         ...         ...
# 135025  1G1RA6E46D      73   464     44      98056.0        2013   CHEVROLET
# 135027  JA4J24A54L     155   401     44      98502.0        2020  MITSUBISHI
# 135029  1G1RD6S56H      25   606     44      98682.0        2017   CHEVROLET
# 135030  1C4JJXN68P      73   509     44      98148.0        2023        JEEP
# 135037  1FADP5CU4E      75   440     44      98366.0        2014        FORD
#
#         Model                   Electric Vehicle Type  \
# 0          71          Battery Electric Vehicle (BEV)
# 1          69          Battery Electric Vehicle (BEV)
# 2          71          Battery Electric Vehicle (BEV)
# 3          71          Battery Electric Vehicle (BEV)
# 4          72          Battery Electric Vehicle (BEV)
# ...       ...                                     ...
# 135025    117  Plug-in Hybrid Electric Vehicle (PHEV)
# 135027     79  Plug-in Hybrid Electric Vehicle (PHEV)
# 135029    117  Plug-in Hybrid Electric Vehicle (PHEV)
# 135030    119  Plug-in Hybrid Electric Vehicle (PHEV)
# 135037     20  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                 Clean Alternative Fuel Vehicle Eligible      220.000000
# 1       Eligibility unknown as battery range has not b...       87.780838
# 2                 Clean Alternative Fuel Vehicle Eligible      266.000000
# 3                 Clean Alternative Fuel Vehicle Eligible      322.000000
# 4                 Clean Alternative Fuel Vehicle Eligible      208.000000
# ...                                                   ...             ...
# 135025            Clean Alternative Fuel Vehicle Eligible       38.000000
# 135027              Not eligible due to low battery range       22.000000
# 135029            Clean Alternative Fuel Vehicle Eligible       53.000000
# 135030              Not eligible due to low battery range       21.000000
# 135037              Not eligible due to low battery range       19.000000
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 0             0.0                  22.0       242565116
# 1             0.0                  10.0       183272785
# 2             0.0                  44.0       112552366
# 3             0.0                  11.0         6336319
# 4         69900.0                  21.0       186212960
# ...           ...                   ...             ...
# 135025        0.0                  11.0       231205173
# 135027        0.0                  35.0       100639514
# 135029        0.0                  17.0       140190424
# 135030        0.0                  33.0       235938776
# 135037        0.0                  26.0       171102032
#
#                                       Vehicle Location  \
# 0        POINT (-122.91310169999997 47.01359260000004)
# 1        POINT (-122.35936399999997 47.97965520000008)
# 2        POINT (-122.09150499999998 47.91555500000004)
# 3       POINT (-122.32981499999994 47.579810000000066)
# 4                 POINT (-122.37507 47.80807000000004)
# ...                                                ...
# 135025   POINT (-122.18050499999998 47.50005500000003)
# 135027            POINT (-122.92145 47.04593500000004)
# 135029   POINT (-122.51464729999998 45.67862000000008)
# 135030                     POINT (-122.32806 47.46155)
# 135037   POINT (-122.63926499999997 47.53730000000007)
#
#                                          Electric Utility  2020 Census Tract
# 0                                  PUGET SOUND ENERGY INC       5.306701e+10
# 1                                  PUGET SOUND ENERGY INC       5.302997e+10
# 2                                  PUGET SOUND ENERGY INC       5.306105e+10
# 3            CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 4                                  PUGET SOUND ENERGY INC       5.306105e+10
# ...                                                   ...                ...
# 135025      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 135027                             PUGET SOUND ENERGY INC       5.306701e+10
# 135029  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       5.301104e+10
# 135030      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 135037                             PUGET SOUND ENERGY INC       5.303509e+10
#
# [135038 rows x 17 columns]

# %%
def create_electric_range_category(df, column='Electric Range'):
    def categorize_range(electric_range):
        if electric_range == 0:
            return 0.0
        elif electric_range < 50:
            return 1.0 #very Short
        elif 50 <= electric_range <= 100:
            return 3.0 #very Short
        elif 100 < electric_range <= 300:
            return 4.0 #"Medium"
        elif 300 < electric_range:
            return 5.0 #long
        else:
            return -1.0

    df['Electric_Range_Category'] = df[column].apply(categorize_range)
    return df

electric_vehicles = create_electric_range_category(electric_vehicles, column='Electric Range')

# %%
#electric_vehicles.dropna(subset=["Electric Range"])
electric_vehicles = electric_vehicles[electric_vehicles['Electric Range'].notna()]

# %%
electric_vehicles['Electric Range'].isna().sum()
# Out:
# 0

# %%
#electric_vehicles['Model Year'] = pd.to_numeric(electric_vehicles['Model Year'], errors="ignore") 

#print(electric_vehicles.dtypes)

#assenger_attributes.drop(columns = ["PassengerId", "Name", "Cabin"])
X = electric_vehicles[['Base MSRP', 'City', 'State', 'County', 'Model', 'Electric Range']]
#X = electric_vehicles.drop(columns = ['Electric Range'])

y = electric_vehicles['Electric_Range_Category']
#scaler = MinMaxScaler()
#y = scaler.fit_transform(electric_vehicles['Electric_Range_Category'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42434)

linear_model = LogisticRegression(C = 1)
#model = LogisticRegression(C = 10e9)
linear_model.fit(X_train, y_train)

y_pred = linear_model.predict(X_test)
# Out:
# c:\python39\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
linear_model.score(X_train,y_train)
# Out:
# 0.9214176143877281

# %%
linear_model.score(X_test,y_test)
# Out:
# 0.9190116508688784

# %%
mlflow.log_artifact("data/Electric_Vehicle_Population_Data.csv")

# %%
#Parameters
mlflow.log_param("C", 1)
mlflow.log_param("train_test_split", False)

# Metics
for train_step in range(100):
    mlflow.log_metric("test_metrics", train_step **2, step = train_step) # accuracy

# %%
mlflow.end_run()
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[345], line 1
# ----> 1 mlflow.end_run()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\mlflow\tracking\fluent.py:434, in end_run(status)
#     432 run = _active_run_stack.pop()
#     433 _last_active_run_id = run.info.run_id
# --> 434 MlflowClient().set_terminated(_last_active_run_id, status)
#     435 if _last_active_run_id in run_id_to_system_metrics_monitor:
#     436     system_metrics_monitor = run_id_to_system_metrics_monitor.pop(_last_active_run_id)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\mlflow\tracking\client.py:1909, in MlflowClient.set_terminated(self, run_id, status, end_time)
#    1864 def set_terminated(
#    1865     self, run_id: str, status: Optional[str] = None, end_time: Optional[int] = None
#    1866 ) -> None:
#    1867     """Set a run's status to terminated.
#    1868
#    1869     :param status: A string value of :py:class:`mlflow.entities.RunStatus`.
#    (...)
#    1907         status: KILLED
#    1908     """
# -> 1909     self._tracking_client.set_terminated(run_id, status, end_time)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\mlflow\tracking\_tracking_service\client.py:575, in TrackingServiceClient.set_terminated(self, run_id, status, end_time)
#     573 end_time = end_time if end_time else get_current_time_millis()
#     574 status = status if status else RunStatus.to_string(RunStatus.FINISHED)
# --> 575 self.store.update_run_info(
#     576     run_id,
#     577     run_status=RunStatus.from_string(status),
#     578     end_time=end_time,
#     579     run_name=None,
#     580 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\mlflow\store\tracking\file_store.py:592, in FileStore.update_run_info(self, run_id, run_status, end_time, run_name)
#     590 _validate_run_id(run_id)
#     591 run_info = self._get_run_info(run_id)
# --> 592 check_run_is_active(run_info)
#     593 new_info = run_info._copy_with_overrides(run_status, end_time, run_name=run_name)
#     594 if run_name:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\mlflow\entities\run_info.py:11, in check_run_is_active(run_info)
#       9 def check_run_is_active(run_info):
#      10     if run_info.lifecycle_stage != LifecycleStage.ACTIVE:
# ---> 11         raise MlflowException(
#      12             f"The run {run_info.run_id} must be in 'active' lifecycle_stage.",
#      13             error_code=INVALID_PARAMETER_VALUE,
#      14         )
#
# MlflowException: The run 018bf706d180475d87a085fce63d5db3 must be in 'active' lifecycle_stage.
